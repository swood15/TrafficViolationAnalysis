# %% [markdown]
# # Project 1 - Stephen's code
# ----
#
# ### Question 5 and 6 Analysis
# * Due to the recent advancment and use of mobile phones while driving, we we wanted to specifically test to see if Men or Women comitted this offense more than the other gender. Mobile phone use can consist of talking or texting. Many states have recently inacted laws prohibiting the use of mobile phones while driving. From the data collected, the data shows Men were caught using their mobile phones while driving more often than Women by almost 6000 more occurences.
# * We also wanted to investigate out of all the violations comitted during this time frame of our data, whether Men or Women were more prone to comitting certain types of violations over the other gender. Our hypothesis for this gender analysis was that both Men and Women comitted violations of each type equally. But the data shows otherwise. Of all the violations, Women only comitted one violation more often than Men, and that was "Failure to Secure Child in Safety Seat", but just by a very slight margin. Of the top 10 most comitted violations, you can see from the graph that Men, and by a wide margin on most violation types, comitted these violations more times than Women. From this analysis, my hypothesis as to why there is such disparity is that Men are typically thrill seekers when it comes to cars and generally don't think of the consequences of related actions.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Plot Style Sheet
from matplotlib import style
style.use('seaborn-white')

# Files to Load 
Traffic_Data_File = "Traffic_Violations_Final.csv"


#Read CSV files
Traffic_Data = pd.read_csv(Traffic_Data_File)


#Display dataframe
Traffic_Data.head()
# Out:
#    Unnamed: 0 Date Of Stop            Time Of Stop  \
# 0           0   11/13/2013   12/30/1899 7:01:00 PM
# 1           1     7/3/2012  12/30/1899 12:02:00 PM
# 2           2     7/3/2012  12/30/1899 12:02:00 PM
# 3           3    9/26/2012  12/30/1899 11:24:00 AM
# 4           4    9/26/2012  12/30/1899 11:24:00 AM
#
#                                    Police District   Latitude  Longitude  \
# 0  6TH DISTRICT, GAITHERSBURG / MONTGOMERY VILLAGE        NaN        NaN
# 1  6TH DISTRICT, GAITHERSBURG / MONTGOMERY VILLAGE  39.135379 -77.210164
# 2  6TH DISTRICT, GAITHERSBURG / MONTGOMERY VILLAGE  39.135379 -77.210164
# 3  6TH DISTRICT, GAITHERSBURG / MONTGOMERY VILLAGE  39.155185 -77.209968
# 4  6TH DISTRICT, GAITHERSBURG / MONTGOMERY VILLAGE  39.155185 -77.209968
#
#       Vehicle Type  Vehicle Year Vehicle Make Vehicle Color Violation Type  \
# 0  02 - Automobile        1998.0        HONDA         GREEN       Citation
# 1  02 - Automobile        1999.0       TOYOTA         GREEN       Citation
# 2  02 - Automobile        1999.0       TOYOTA         GREEN       Citation
# 3  02 - Automobile        2000.0         FORD         GREEN       Citation
# 4  02 - Automobile        2000.0         FORD         GREEN       Citation
#
#         Charge   Race  Gender        Arrest Type  \
# 0    13-401(h)  WHITE  FEMALE  A - Marked Patrol
# 1     21-801.1  WHITE  FEMALE  A - Marked Patrol
# 2    21-309(b)  WHITE  FEMALE  A - Marked Patrol
# 3  22-412.3(b)  WHITE  FEMALE  A - Marked Patrol
# 4  22-412.3(c)  WHITE  FEMALE  A - Marked Patrol
#
#                                            Violation  \
# 0  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 1  EXCEEDING MAXIMUM SPEED 83 MPH IN A POSTED 55 ...
# 2                  DRIVER CHANGING LANES WHEN UNSAFE
# 3                OPERATOR NOT RESTRAINED BY SEATBELT
# 4  PASSENGER AGE 16 OR MORE IN OUTBOARD FRONT SEA...
#
#                                          Description  Record ID
# 0  DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION     283685
# 1                   EXCEEDING THE POSTED SPEED LIMIT     283687
# 2                     UNSAFE OR IMPROPER LANE CHANGE     283686
# 3  DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT ...     283697
# 4  DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT ...     283698

# %%
#list column headers
list(Traffic_Data)
# Out:
# ['Unnamed: 0',
#  'Date Of Stop',
#  'Time Of Stop',
#  'Police District',
#  'Latitude',
#  'Longitude',
#  'Vehicle Type',
#  'Vehicle Year',
#  'Vehicle Make',
#  'Vehicle Color',
#  'Violation Type',
#  'Charge',
#  'Race',
#  'Gender',
#  'Arrest Type',
#  'Violation',
#  'Description',
#  'Record ID']

# %%
#find unique values for Description column
Traffic_Data["Description"].unique()
# Out:
# array(['DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION',
#        'EXCEEDING THE POSTED SPEED LIMIT',
#        'UNSAFE OR IMPROPER LANE CHANGE',
#        'DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT',
#        'DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE',
#        'DRIVING WITHOUT INSURANCE',
#        'IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY OR USE OF VEHICLE REGISTRATION',
#        'FAILURE TO OBEY TRAFFIC CONTROL DEVICE',
#        'FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT',
#        'DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF ALCOHOL AND/OR DRUGS',
#        'PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION',
#        'FAILURE TO YIELD RIGHT OF WAY',
#        'RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING',
#        'DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRUDENT SPEED',
#        'FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADWAY WHEN REQUIRED',
#        'UNSAFE OR IMPROPER PASSING',
#        'DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, OR INOPERATIVE EQUIPMENT',
#        'DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED',
#        'PARKING IN PROHIBITED LOCATION OR MANNER',
#        'FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF CHANGE OF ADDRESS WITHIN 30 DAYS',
#        'DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE AND PRUDENT',
#        'FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJACENT TO STOPPED EMERGENCY VEHICLE',
#        'KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UNAUTHORIZED PERSON',
#        'FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLISION',
#        'PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL',
#        'PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT INTERSECTIONS HAVING TRAFFIC CONTROL SIGNAL',
#        'WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION OF POLICE OFFICER',
#        'DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE', 'MISC',
#        'FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED DAMAGED VEHICLE',
#        'DRIVING WITH OBSTRUCTED VIEW',
#        'DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/IN BOTH EARS',
#        'UNSAFE BACKING OF VEHICLE',
#        'FAILURE TO REMAIN AT SCENE OF ACCIDENT',
#        'FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT',
#        'STOPPING VEHICLE IMPROPERLY', 'DRIVER FAILURE TO SIGNAL',
#        'DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF RENTAL AGREEMENT',
#        'WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDING NORMAL AND REASONABLE TRAFFIC MOVEMENT',
#        'LITTERING',
#        'DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNERS CONSENT',
#        'DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERATING WINDSHIELD WIPERS',
#        'FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE',
#        'ATTEMPT BY DRIVER TO ELUDE POLICE',
#        'USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSARY FOR SAFETY',
#        'DRIFTING', 'DRIVING WITH UNSECURED OR UNSAFE LOAD',
#        'FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDER REASONABLE ASSISTANCE TO INJURED PERSON',
#        'DRIVER SPINNING WHEELS', 'PARTICIPATING IN SPEED CONTEST',
#        'UNLAWFUL USE OF HISTORIC VEHICLE',
#        'DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS CERTIFICATE IN POSSESSION',
#        'FAILING TO DISPLAY PROPER VEHICLE ID',
#        'ABANDONING VEHICLE ON PUBLIC PROPERTY',
#        'FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON MOTOR SCOOTER',
#        'EXCEEDING ALLOWABLE WEIGHT',
#        'DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO'], dtype=object)

# %%
#Count total violations recorded by each gender
#notice how there are some unknown genders
Traffic_Data.Gender.value_counts()
# Out:
# MALE       930143
# FEMALE     456079
# UNKNOWN      1620
# Name: Gender, dtype: int64

# %%
#group by description
Traffic_Data_by_Description = Traffic_Data.groupby(["Description"]).count()
Traffic_Data_by_Description
# Out:
#                                                     Unnamed: 0  Date Of Stop  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                      138           138
# ATTEMPT BY DRIVER TO ELUDE POLICE                          930           930
# DRIFTING                                                    30            30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT       31317         31317
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE              3057          3057
# DRIVER FAILURE TO SIGNAL                                  5436          5436
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...        6300          6300
# DRIVER SPINNING WHEELS                                     796           796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE        38786         38786
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...         383           383
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO          140           140
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...         201           201
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...       25751         25751
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...       49977         49977
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...        2634          2634
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...      161575        161575
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...        1890          1890
# DRIVING WITH OBSTRUCTED VIEW                              8901          8901
# DRIVING WITH UNSECURED OR UNSAFE LOAD                      856           856
# DRIVING WITHOUT INSURANCE                                16248         16248
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED         33051         33051
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...         387           387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION       354488        354488
# EXCEEDING ALLOWABLE WEIGHT                                 180           180
# EXCEEDING THE POSTED SPEED LIMIT                        178255        178255
# FAILING TO DISPLAY PROPER VEHICLE ID                       885           885
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...         151           151
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...       18408         18408
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...        9610          9610
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...       16193         16193
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...         231           231
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...       10827         10827
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...         783           783
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                  243733        243733
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE          1782          1782
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                    1934          1934
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT          727           727
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT              4578          4578
# FAILURE TO YIELD RIGHT OF WAY                            21721         21721
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...       44689         44689
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...         863           863
# LITTERING                                                  715           715
# MISC                                                      2372          2372
# PARKING IN PROHIBITED LOCATION OR MANNER                  8678          8678
# PARTICIPATING IN SPEED CONTEST                             259           259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...        3187          3187
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL         3903          3903
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION         8358          8358
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING               26143         26143
# STOPPING VEHICLE IMPROPERLY                               2274          2274
# UNLAWFUL USE OF HISTORIC VEHICLE                           482           482
# UNSAFE BACKING OF VEHICLE                                 1468          1468
# UNSAFE OR IMPROPER LANE CHANGE                           22410         22410
# UNSAFE OR IMPROPER PASSING                                5420          5420
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...         603           603
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...         585           585
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...        2163          2163
#
#                                                     Time Of Stop  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                        138
# ATTEMPT BY DRIVER TO ELUDE POLICE                            930
# DRIFTING                                                      30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT         31317
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE                3057
# DRIVER FAILURE TO SIGNAL                                    5436
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...          6300
# DRIVER SPINNING WHEELS                                       796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE          38786
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...           383
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO            140
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...           201
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...         25751
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...         49977
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...          2634
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...        161575
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...          1890
# DRIVING WITH OBSTRUCTED VIEW                                8901
# DRIVING WITH UNSECURED OR UNSAFE LOAD                        856
# DRIVING WITHOUT INSURANCE                                  16248
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED           33051
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...           387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION         354488
# EXCEEDING ALLOWABLE WEIGHT                                   180
# EXCEEDING THE POSTED SPEED LIMIT                          178255
# FAILING TO DISPLAY PROPER VEHICLE ID                         885
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...           151
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...         18408
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...          9610
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...         16193
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...           231
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...         10827
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...           783
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                    243733
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE            1782
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                      1934
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT            727
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT                4578
# FAILURE TO YIELD RIGHT OF WAY                              21721
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...         44689
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...           863
# LITTERING                                                    715
# MISC                                                        2372
# PARKING IN PROHIBITED LOCATION OR MANNER                    8678
# PARTICIPATING IN SPEED CONTEST                               259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...          3187
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL           3903
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION           8358
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                 26143
# STOPPING VEHICLE IMPROPERLY                                 2274
# UNLAWFUL USE OF HISTORIC VEHICLE                             482
# UNSAFE BACKING OF VEHICLE                                   1468
# UNSAFE OR IMPROPER LANE CHANGE                             22410
# UNSAFE OR IMPROPER PASSING                                  5420
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...           603
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...           585
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...          2163
#
#                                                     Police District  Latitude  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                           138       127
# ATTEMPT BY DRIVER TO ELUDE POLICE                               930       760
# DRIFTING                                                         30        27
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT            31317     29272
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE                   3057      2809
# DRIVER FAILURE TO SIGNAL                                       5436      5112
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...             6300      5790
# DRIVER SPINNING WHEELS                                          796       716
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE             38786     36625
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...              383       331
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO               140       128
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...              201       157
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...            25751     24007
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...            49977     38632
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...             2634      2453
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...           161573    151807
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...             1890      1752
# DRIVING WITH OBSTRUCTED VIEW                                   8901      8466
# DRIVING WITH UNSECURED OR UNSAFE LOAD                           856       805
# DRIVING WITHOUT INSURANCE                                     16248     15205
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED              33051     30520
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...              387       374
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION            354484    331156
# EXCEEDING ALLOWABLE WEIGHT                                      180       174
# EXCEEDING THE POSTED SPEED LIMIT                             178255    166847
# FAILING TO DISPLAY PROPER VEHICLE ID                            885       831
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...              151       132
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...            18408     17299
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...             9610      9128
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...            16193     14692
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...              231       210
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...            10827      9744
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...              783       666
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                       243730    227165
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE               1782      1684
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                         1934      1711
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT               727       615
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT                   4578      4298
# FAILURE TO YIELD RIGHT OF WAY                                 21721     20374
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...            44689     41938
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...              863       794
# LITTERING                                                       715       658
# MISC                                                           2372      2156
# PARKING IN PROHIBITED LOCATION OR MANNER                       8678      8154
# PARTICIPATING IN SPEED CONTEST                                  259       235
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...             3187      2989
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL              3903      3702
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION              8358      7843
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                    26143     23009
# STOPPING VEHICLE IMPROPERLY                                    2274      2160
# UNLAWFUL USE OF HISTORIC VEHICLE                                482       459
# UNSAFE BACKING OF VEHICLE                                      1468      1316
# UNSAFE OR IMPROPER LANE CHANGE                                22409     20651
# UNSAFE OR IMPROPER PASSING                                     5420      4966
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...              603       581
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...              585       519
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...             2163      2004
#
#                                                     Longitude  Vehicle Type  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                     127           138
# ATTEMPT BY DRIVER TO ELUDE POLICE                         760           930
# DRIFTING                                                   27            30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT      29272         31317
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE             2809          3057
# DRIVER FAILURE TO SIGNAL                                 5112          5436
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...       5790          6300
# DRIVER SPINNING WHEELS                                    716           796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE       36625         38786
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...        331           383
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO         128           140
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...        157           201
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...      24007         25751
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...      38632         49977
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...       2453          2634
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...     151807        161575
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...       1752          1890
# DRIVING WITH OBSTRUCTED VIEW                             8466          8901
# DRIVING WITH UNSECURED OR UNSAFE LOAD                     805           856
# DRIVING WITHOUT INSURANCE                               15205         16248
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED        30520         33051
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...        374           387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION      331156        354488
# EXCEEDING ALLOWABLE WEIGHT                                174           180
# EXCEEDING THE POSTED SPEED LIMIT                       166847        178255
# FAILING TO DISPLAY PROPER VEHICLE ID                      831           885
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...        132           151
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...      17299         18408
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...       9128          9610
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...      14692         16193
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...        210           231
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...       9744         10827
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...        666           783
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                 227165        243733
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE         1684          1782
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                   1711          1934
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT         615           727
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT             4298          4578
# FAILURE TO YIELD RIGHT OF WAY                           20374         21721
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...      41938         44689
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...        794           863
# LITTERING                                                 658           715
# MISC                                                     2156          2372
# PARKING IN PROHIBITED LOCATION OR MANNER                 8154          8678
# PARTICIPATING IN SPEED CONTEST                            235           259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...       2989          3187
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL        3702          3903
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION        7843          8358
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING              23009         26143
# STOPPING VEHICLE IMPROPERLY                              2160          2274
# UNLAWFUL USE OF HISTORIC VEHICLE                          459           482
# UNSAFE BACKING OF VEHICLE                                1316          1468
# UNSAFE OR IMPROPER LANE CHANGE                          20651         22410
# UNSAFE OR IMPROPER PASSING                               4966          5420
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...        581           603
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...        519           585
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...       2004          2163
#
#                                                     Vehicle Year  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                        137
# ATTEMPT BY DRIVER TO ELUDE POLICE                            918
# DRIFTING                                                      30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT         31210
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE                3049
# DRIVER FAILURE TO SIGNAL                                    5427
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...          6293
# DRIVER SPINNING WHEELS                                       796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE          38740
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...           383
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO            131
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...           192
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...         25689
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...         49871
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...          2623
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...        161403
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...          1885
# DRIVING WITH OBSTRUCTED VIEW                                8888
# DRIVING WITH UNSECURED OR UNSAFE LOAD                        855
# DRIVING WITHOUT INSURANCE                                  16173
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED           33009
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...           387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION         353566
# EXCEEDING ALLOWABLE WEIGHT                                   180
# EXCEEDING THE POSTED SPEED LIMIT                          178081
# FAILING TO DISPLAY PROPER VEHICLE ID                         883
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...           151
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...         18361
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...          9601
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...         16162
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...           208
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...         10792
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...           782
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                    242835
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE            1782
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                      1929
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT            718
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT                4570
# FAILURE TO YIELD RIGHT OF WAY                              21635
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...         44568
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...           768
# LITTERING                                                    700
# MISC                                                        2272
# PARKING IN PROHIBITED LOCATION OR MANNER                    8598
# PARTICIPATING IN SPEED CONTEST                               259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...            12
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL            114
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION           8350
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                 26085
# STOPPING VEHICLE IMPROPERLY                                 2271
# UNLAWFUL USE OF HISTORIC VEHICLE                             481
# UNSAFE BACKING OF VEHICLE                                   1468
# UNSAFE OR IMPROPER LANE CHANGE                             22363
# UNSAFE OR IMPROPER PASSING                                  5397
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...           601
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...           569
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...          2157
#
#                                                     Vehicle Make  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                        138
# ATTEMPT BY DRIVER TO ELUDE POLICE                            930
# DRIFTING                                                      30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT         31317
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE                3057
# DRIVER FAILURE TO SIGNAL                                    5436
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...          6300
# DRIVER SPINNING WHEELS                                       796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE          38786
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...           383
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO            140
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...           201
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...         25751
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...         49977
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...          2634
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...        161575
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...          1890
# DRIVING WITH OBSTRUCTED VIEW                                8901
# DRIVING WITH UNSECURED OR UNSAFE LOAD                        856
# DRIVING WITHOUT INSURANCE                                  16248
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED           33051
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...           387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION         354488
# EXCEEDING ALLOWABLE WEIGHT                                   180
# EXCEEDING THE POSTED SPEED LIMIT                          178255
# FAILING TO DISPLAY PROPER VEHICLE ID                         885
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...           151
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...         18408
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...          9610
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...         16193
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...           231
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...         10827
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...           783
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                    243733
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE            1782
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                      1934
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT            727
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT                4578
# FAILURE TO YIELD RIGHT OF WAY                              21721
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...         44689
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...           863
# LITTERING                                                    715
# MISC                                                        2372
# PARKING IN PROHIBITED LOCATION OR MANNER                    8678
# PARTICIPATING IN SPEED CONTEST                               259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...          3187
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL           3903
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION           8358
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                 26143
# STOPPING VEHICLE IMPROPERLY                                 2274
# UNLAWFUL USE OF HISTORIC VEHICLE                             482
# UNSAFE BACKING OF VEHICLE                                   1468
# UNSAFE OR IMPROPER LANE CHANGE                             22410
# UNSAFE OR IMPROPER PASSING                                  5420
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...           603
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...           585
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...          2163
#
#                                                     Vehicle Color  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                         137
# ATTEMPT BY DRIVER TO ELUDE POLICE                             916
# DRIFTING                                                       30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT          30643
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE                 3054
# DRIVER FAILURE TO SIGNAL                                     5428
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...           6290
# DRIVER SPINNING WHEELS                                        796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE           38709
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...            382
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO             131
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...            192
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...          25682
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...          49858
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...           2597
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...         160903
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...           1887
# DRIVING WITH OBSTRUCTED VIEW                                 8890
# DRIVING WITH UNSECURED OR UNSAFE LOAD                         853
# DRIVING WITHOUT INSURANCE                                   16207
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED            32974
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...            387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION          352941
# EXCEEDING ALLOWABLE WEIGHT                                    180
# EXCEEDING THE POSTED SPEED LIMIT                           175892
# FAILING TO DISPLAY PROPER VEHICLE ID                          884
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...            147
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...          18362
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...           9605
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...          16145
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...            223
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...          10798
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...            781
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                     240819
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE             1778
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                       1923
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT             717
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT                 4571
# FAILURE TO YIELD RIGHT OF WAY                               21620
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...          44561
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...            771
# LITTERING                                                     699
# MISC                                                         2300
# PARKING IN PROHIBITED LOCATION OR MANNER                     8577
# PARTICIPATING IN SPEED CONTEST                                259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...              9
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL              79
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION            8329
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                  26071
# STOPPING VEHICLE IMPROPERLY                                  2270
# UNLAWFUL USE OF HISTORIC VEHICLE                              482
# UNSAFE BACKING OF VEHICLE                                    1466
# UNSAFE OR IMPROPER LANE CHANGE                              22222
# UNSAFE OR IMPROPER PASSING                                   5252
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...            602
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...            566
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...           2158
#
#                                                     Violation Type  Charge  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                          138     138
# ATTEMPT BY DRIVER TO ELUDE POLICE                              930     930
# DRIFTING                                                        30      30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT           31317   31317
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE                  3057    3057
# DRIVER FAILURE TO SIGNAL                                      5436    5436
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...            6300    6300
# DRIVER SPINNING WHEELS                                         796     796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE            38786   38786
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...             383     383
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO              140     140
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...             201     201
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...           25751   25751
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...           49977   49977
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...            2634    2634
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...          161575  161575
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...            1890    1890
# DRIVING WITH OBSTRUCTED VIEW                                  8901    8901
# DRIVING WITH UNSECURED OR UNSAFE LOAD                          856     856
# DRIVING WITHOUT INSURANCE                                    16248   16248
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED             33051   33051
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...             387     387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION           354488  354488
# EXCEEDING ALLOWABLE WEIGHT                                     180     180
# EXCEEDING THE POSTED SPEED LIMIT                            178255  178255
# FAILING TO DISPLAY PROPER VEHICLE ID                           885     885
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...             151     151
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...           18408   18408
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...            9610    9610
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...           16193   16193
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...             231     231
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...           10827   10827
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...             783     783
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                      243733  243733
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE              1782    1782
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                        1934    1934
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT              727     727
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT                  4578    4578
# FAILURE TO YIELD RIGHT OF WAY                                21721   21721
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...           44689   44689
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...             863     863
# LITTERING                                                      715     715
# MISC                                                          2372    2372
# PARKING IN PROHIBITED LOCATION OR MANNER                      8678    8678
# PARTICIPATING IN SPEED CONTEST                                 259     259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...            3187    3187
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL             3903    3903
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION             8358    8358
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                   26143   26143
# STOPPING VEHICLE IMPROPERLY                                   2274    2274
# UNLAWFUL USE OF HISTORIC VEHICLE                               482     482
# UNSAFE BACKING OF VEHICLE                                     1468    1468
# UNSAFE OR IMPROPER LANE CHANGE                               22410   22410
# UNSAFE OR IMPROPER PASSING                                    5420    5420
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...             603     603
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...             585     585
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...            2163    2163
#
#                                                       Race  Gender  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                  138     138
# ATTEMPT BY DRIVER TO ELUDE POLICE                      930     930
# DRIFTING                                                30      30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT   31317   31317
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE          3057    3057
# DRIVER FAILURE TO SIGNAL                              5436    5436
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...    6300    6300
# DRIVER SPINNING WHEELS                                 796     796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE    38786   38786
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...     383     383
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO      140     140
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...     201     201
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...   25751   25751
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...   49977   49977
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...    2634    2634
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...  161575  161575
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...    1890    1890
# DRIVING WITH OBSTRUCTED VIEW                          8901    8901
# DRIVING WITH UNSECURED OR UNSAFE LOAD                  856     856
# DRIVING WITHOUT INSURANCE                            16248   16248
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED     33051   33051
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...     387     387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION   354488  354488
# EXCEEDING ALLOWABLE WEIGHT                             180     180
# EXCEEDING THE POSTED SPEED LIMIT                    178255  178255
# FAILING TO DISPLAY PROPER VEHICLE ID                   885     885
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...     151     151
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...   18408   18408
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...    9610    9610
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...   16193   16193
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...     231     231
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...   10827   10827
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...     783     783
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE              243733  243733
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE      1782    1782
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                1934    1934
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT      727     727
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT          4578    4578
# FAILURE TO YIELD RIGHT OF WAY                        21721   21721
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...   44689   44689
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...     863     863
# LITTERING                                              715     715
# MISC                                                  2372    2372
# PARKING IN PROHIBITED LOCATION OR MANNER              8678    8678
# PARTICIPATING IN SPEED CONTEST                         259     259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...    3187    3187
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL     3903    3903
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION     8358    8358
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING           26143   26143
# STOPPING VEHICLE IMPROPERLY                           2274    2274
# UNLAWFUL USE OF HISTORIC VEHICLE                       482     482
# UNSAFE BACKING OF VEHICLE                             1468    1468
# UNSAFE OR IMPROPER LANE CHANGE                       22410   22410
# UNSAFE OR IMPROPER PASSING                            5420    5420
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...     603     603
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...     585     585
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...    2163    2163
#
#                                                     Arrest Type  Violation  \
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                       138        138
# ATTEMPT BY DRIVER TO ELUDE POLICE                           930        930
# DRIFTING                                                     30         30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT        31317      31317
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE               3057       3057
# DRIVER FAILURE TO SIGNAL                                   5436       5436
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...         6300       6300
# DRIVER SPINNING WHEELS                                      796        796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE         38786      38786
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...          383        383
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO           140        140
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...          201        201
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...        25751      25751
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...        49977      49977
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...         2634       2634
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...       161575     161575
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...         1890       1890
# DRIVING WITH OBSTRUCTED VIEW                               8901       8901
# DRIVING WITH UNSECURED OR UNSAFE LOAD                       856        856
# DRIVING WITHOUT INSURANCE                                 16248      16248
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED          33051      33051
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...          387        387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION        354488     354488
# EXCEEDING ALLOWABLE WEIGHT                                  180        180
# EXCEEDING THE POSTED SPEED LIMIT                         178255     178255
# FAILING TO DISPLAY PROPER VEHICLE ID                        885        885
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...          151        151
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...        18408      18408
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...         9610       9610
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...        16193      16193
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...          231        231
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...        10827      10827
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...          783        783
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                   243733     243733
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE           1782       1782
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                     1934       1934
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT           727        727
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT               4578       4578
# FAILURE TO YIELD RIGHT OF WAY                             21721      21721
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...        44689      44689
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...          863        863
# LITTERING                                                   715        715
# MISC                                                       2372       2372
# PARKING IN PROHIBITED LOCATION OR MANNER                   8678       8678
# PARTICIPATING IN SPEED CONTEST                              259        259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...         3187       3187
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL          3903       3903
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION          8358       8358
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                26143      26143
# STOPPING VEHICLE IMPROPERLY                                2274       2274
# UNLAWFUL USE OF HISTORIC VEHICLE                            482        482
# UNSAFE BACKING OF VEHICLE                                  1468       1468
# UNSAFE OR IMPROPER LANE CHANGE                            22410      22410
# UNSAFE OR IMPROPER PASSING                                 5420       5420
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...          603        603
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...          585        585
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...         2163       2163
#
#                                                     Record ID
# Description
# ABANDONING VEHICLE ON PUBLIC PROPERTY                     138
# ATTEMPT BY DRIVER TO ELUDE POLICE                         930
# DRIFTING                                                   30
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT      31317
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE             3057
# DRIVER FAILURE TO SIGNAL                                 5436
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...       6300
# DRIVER SPINNING WHEELS                                    796
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE       38786
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...        383
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO         140
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...        201
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...      25751
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...      49977
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...       2634
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...     161575
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...       1890
# DRIVING WITH OBSTRUCTED VIEW                             8901
# DRIVING WITH UNSECURED OR UNSAFE LOAD                     856
# DRIVING WITHOUT INSURANCE                               16248
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED        33051
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...        387
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION      354488
# EXCEEDING ALLOWABLE WEIGHT                                180
# EXCEEDING THE POSTED SPEED LIMIT                       178255
# FAILING TO DISPLAY PROPER VEHICLE ID                      885
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...        151
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...      18408
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...       9610
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...      16193
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...        231
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...      10827
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...        783
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                 243733
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE         1782
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                   1934
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT         727
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT             4578
# FAILURE TO YIELD RIGHT OF WAY                           21721
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...      44689
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...        863
# LITTERING                                                 715
# MISC                                                     2372
# PARKING IN PROHIBITED LOCATION OR MANNER                 8678
# PARTICIPATING IN SPEED CONTEST                            259
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...       3187
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL        3903
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION        8358
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING              26143
# STOPPING VEHICLE IMPROPERLY                              2274
# UNLAWFUL USE OF HISTORIC VEHICLE                          482
# UNSAFE BACKING OF VEHICLE                                1468
# UNSAFE OR IMPROPER LANE CHANGE                          22410
# UNSAFE OR IMPROPER PASSING                               5420
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...        603
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...        585
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...       2163

# %%
#filter data to show violations for each gender
Male_Traffic_Data_df = Traffic_Data.loc[Traffic_Data["Gender"] == "MALE", :]
Female_Traffic_Data_df = Traffic_Data.loc[Traffic_Data["Gender"] == "FEMALE", :]
Male_Traffic_Data_df.head()
# Out:
#      Unnamed: 0 Date Of Stop            Time Of Stop          Police District  \
# 616         616    1/18/2012   12/30/1899 3:42:00 PM  1ST DISTRICT, ROCKVILLE
# 617         617    1/18/2012   12/30/1899 3:42:00 PM  1ST DISTRICT, ROCKVILLE
# 618         618     8/3/2012   12/30/1899 2:40:00 PM  1ST DISTRICT, ROCKVILLE
# 619         619    1/13/2016   12/30/1899 4:12:00 PM  1ST DISTRICT, ROCKVILLE
# 620         620     7/2/2015  12/30/1899 11:32:00 PM  1ST DISTRICT, ROCKVILLE
#
#       Latitude  Longitude           Vehicle Type  Vehicle Year Vehicle Make  \
# 616  39.124092 -77.363994     03 - Station Wagon        2001.0        DODGE
# 617  39.124092 -77.363994     03 - Station Wagon        2001.0        DODGE
# 618  39.054193 -77.189437  05 - Light Duty Truck        2003.0         FORD
# 619  39.056498 -77.083617             28 - Other           NaN        OTHER
# 620  39.084550 -77.118550           29 - Unknown           NaN        OTHER
#
#     Vehicle Color Violation Type     Charge      Race Gender  \
# 616           NaN       Citation  16-303(h)  HISPANIC   MALE
# 617           NaN       Citation  21-307(b)  HISPANIC   MALE
# 618           NaN       Citation  13-401(h)  HISPANIC   MALE
# 619           NaN       Citation  21-503(c)  HISPANIC   MALE
# 620           NaN       Citation   22-201.1  HISPANIC   MALE
#
#            Arrest Type                                          Violation  \
# 616  A - Marked Patrol  DRIVING MOTOR VEH WHILE LIC SUSPENDED UNDER 17106
# 617  A - Marked Patrol                         PASSING IN NO PASSING ZONE
# 618  A - Marked Patrol  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 619  A - Marked Patrol  PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT I...
# 620  A - Marked Patrol  FAILURE OF VEH ON HWY TO DISPLAY LIGHTED LAMPS...
#
#                                            Description  Record ID
# 616  DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION     662212
# 617                         UNSAFE OR IMPROPER PASSING     662213
# 618  DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION     662236
# 619  PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT I...     662325
# 620   DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED     662348

# %%
#Creating series in order to create a new dataframes that we will use as basis for our analysis
#do value counts for each gender to see how many times each gender comitted each violation description
#we will use these series to create new columns in a new dataframe we will create to compare male vs female violations
Description_Male_Counts = Male_Traffic_Data_df["Description"].value_counts()

Description_Female_Counts = Female_Traffic_Data_df["Description"].value_counts()

#Adding of each gender counts to get sum totals so we can find out top 10 most committed violations
Sum_of_Male_Female_Counts = Description_Male_Counts + Description_Female_Counts

# %%
#create new dataframe with the series we found above to compare male vs female violation descriptions comitted
Description_Analysis_by_gender_df = pd.DataFrame({"Male description counts": Description_Male_Counts,
                                                  "Female description counts": Description_Female_Counts,
                                                 "Sum of counts": Sum_of_Male_Female_Counts})

#fill in NA values with zero since some violation descriptions were not comitted by any females
#for example no females comitted Driving motor vehicle when not qualified to do so
Description_Analysis_by_gender_df["Female description counts"].fillna(value=0, inplace=True)

#create new dataframe that is sorted by Sum of counts so we can use as basis for top10 analysis
#sort the dataframe descending on Sum of gender description counts column so we can find the top 10 most comitted violation descriptions
Description_Analysis_top10 = Description_Analysis_by_gender_df.sort_values(by=["Sum of counts"], ascending=False)

Description_Analysis_top10
# Out:
#                                                     Male description counts  \
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION                    241392
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                               153962
# EXCEEDING THE POSTED SPEED LIMIT                                     109385
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...                   116590
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...                    39195
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...                    33293
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE                     22129
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED                      19614
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT                    23175
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                            19751
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...                    18546
# UNSAFE OR IMPROPER LANE CHANGE                                        15342
# FAILURE TO YIELD RIGHT OF WAY                                         12761
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...                    11356
# DRIVING WITHOUT INSURANCE                                             11008
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...                    10430
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...                     7541
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...                     6045
# DRIVING WITH OBSTRUCTED VIEW                                           6238
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION                      5943
# PARKING IN PROHIBITED LOCATION OR MANNER                               5031
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...                     4363
# DRIVER FAILURE TO SIGNAL                                               4155
# UNSAFE OR IMPROPER PASSING                                             3360
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT                           2273
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL                      2626
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...                     2117
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE                           1976
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...                     1903
# MISC                                                                   1867
# STOPPING VEHICLE IMPROPERLY                                            1528
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...                     1443
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                                 1450
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...                     1869
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE                       1118
# UNSAFE BACKING OF VEHICLE                                              1037
# ATTEMPT BY DRIVER TO ELUDE POLICE                                       844
# FAILING TO DISPLAY PROPER VEHICLE ID                                    874
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...                      475
# DRIVING WITH UNSECURED OR UNSAFE LOAD                                   813
# DRIVER SPINNING WHEELS                                                  748
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...                      548
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT                       560
# LITTERING                                                               515
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...                      408
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...                      416
# UNLAWFUL USE OF HISTORIC VEHICLE                                        434
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...                      230
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...                      281
# PARTICIPATING IN SPEED CONTEST                                          246
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...                      214
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...                      169
# EXCEEDING ALLOWABLE WEIGHT                                              175
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...                      126
# ABANDONING VEHICLE ON PUBLIC PROPERTY                                    89
# DRIFTING                                                                 26
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO                       140
#
#                                                     Female description counts  \
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION                    112910.0
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                                89757.0
# EXCEEDING THE POSTED SPEED LIMIT                                      68863.0
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...                    44970.0
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...                    10780.0
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...                    11354.0
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE                     16657.0
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED                      13437.0
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT                     8140.0
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                             6387.0
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...                     7200.0
# UNSAFE OR IMPROPER LANE CHANGE                                         7067.0
# FAILURE TO YIELD RIGHT OF WAY                                          8955.0
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...                     7051.0
# DRIVING WITHOUT INSURANCE                                              5233.0
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...                     5745.0
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...                     3284.0
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...                     3564.0
# DRIVING WITH OBSTRUCTED VIEW                                           2657.0
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION                      2415.0
# PARKING IN PROHIBITED LOCATION OR MANNER                               2451.0
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...                     1931.0
# DRIVER FAILURE TO SIGNAL                                               1281.0
# UNSAFE OR IMPROPER PASSING                                             2059.0
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT                           2305.0
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL                      1276.0
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...                     1070.0
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE                           1081.0
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...                      731.0
# MISC                                                                    492.0
# STOPPING VEHICLE IMPROPERLY                                             690.0
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...                      720.0
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                                  482.0
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...                       21.0
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE                        664.0
# UNSAFE BACKING OF VEHICLE                                               430.0
# ATTEMPT BY DRIVER TO ELUDE POLICE                                        86.0
# FAILING TO DISPLAY PROPER VEHICLE ID                                     11.0
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...                      388.0
# DRIVING WITH UNSECURED OR UNSAFE LOAD                                    43.0
# DRIVER SPINNING WHEELS                                                   48.0
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...                      235.0
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT                       166.0
# LITTERING                                                               200.0
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...                      195.0
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...                      169.0
# UNLAWFUL USE OF HISTORIC VEHICLE                                         48.0
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...                      157.0
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...                      102.0
# PARTICIPATING IN SPEED CONTEST                                           13.0
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...                       17.0
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...                       32.0
# EXCEEDING ALLOWABLE WEIGHT                                                5.0
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...                       25.0
# ABANDONING VEHICLE ON PUBLIC PROPERTY                                    25.0
# DRIFTING                                                                  4.0
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO                         0.0
#
#                                                     Sum of counts
# DRIVING WITHOUT VALID LICENSE AND/OR REGISTRATION        354302.0
# FAILURE TO OBEY TRAFFIC CONTROL DEVICE                   243719.0
# EXCEEDING THE POSTED SPEED LIMIT                         178248.0
# DRIVING VEHICLE WITH UNAUTHORIZED, INADEQUATE, ...       161560.0
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF AL...        49975.0
# IMPROPER, FRAUDULENT, OR UNAUTHORIZED DISPLAY O...        44647.0
# DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE         38786.0
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHEN REQUIRED          33051.0
# DRIVER AND/OR OCCUPANT NOT RESTRAINED BY SEAT BELT        31315.0
# RECKLESS, NEGLIGENT, OR AGGRESSIVE DRIVING                26138.0
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRU...        25746.0
# UNSAFE OR IMPROPER LANE CHANGE                            22409.0
# FAILURE TO YIELD RIGHT OF WAY                             21716.0
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF...        18407.0
# DRIVING WITHOUT INSURANCE                                 16241.0
# FAILURE TO CONTROL VEHICLE SPEED TO AVOID COLLI...        16175.0
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADW...        10825.0
# FAILURE TO CHANGE TO LANE NOT IMMEDIATELY ADJAC...         9609.0
# DRIVING WITH OBSTRUCTED VIEW                               8895.0
# PROVISIONAL DRIVER WITHOUT AUTHORIZED SUPERVISION          8358.0
# PARKING IN PROHIBITED LOCATION OR MANNER                   7482.0
# DRIVER FOLLOWING VEHICLE CLOSER THAN REASONABLE...         6294.0
# DRIVER FAILURE TO SIGNAL                                   5436.0
# UNSAFE OR IMPROPER PASSING                                 5419.0
# FAILURE TO SECURE CHILD IN CHILD SAFETY SEAT               4578.0
# PEDESTRIAN FAILURE TO OBEY TRAFFIC CONTROL SIGNAL          3902.0
# PEDESTRIAN CROSSING ROADWAY BETWEEN ADJACENT IN...         3187.0
# DRIVER FAILURE TO CURB UPON SIGNAL BY POLICE               3057.0
# DRIVING VEHICLE WHILE WEARING HEADPHONES OVER/I...         2634.0
# MISC                                                       2359.0
# STOPPING VEHICLE IMPROPERLY                                2218.0
# WILLFULLY DRIVING VEHICLE AT SLOW SPEED IMPEDIN...         2163.0
# FAILURE TO REMAIN AT SCENE OF ACCIDENT                     1932.0
# DRIVING VEHICLE WITHOUT VALID MEDICAL EXAMINERS...         1890.0
# FAILURE TO REDUCE LIGHT WHEN APPROACHING VEHICLE           1782.0
# UNSAFE BACKING OF VEHICLE                                  1467.0
# ATTEMPT BY DRIVER TO ELUDE POLICE                           930.0
# FAILING TO DISPLAY PROPER VEHICLE ID                        885.0
# KNOWINGLY PERMITTING VEHICLE TO BE DRIVEN BY UN...          863.0
# DRIVING WITH UNSECURED OR UNSAFE LOAD                       856.0
# DRIVER SPINNING WHEELS                                      796.0
# FAILURE TO FURNISH WRITTEN INFO ON UNATTENDED D...          783.0
# FAILURE TO REPORT ACCIDENT OR GIVING FALSE REPORT           726.0
# LITTERING                                                   715.0
# USE OF VEHICLE HORN WHEN NOT REASONABLY NECESSA...          603.0
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION...          585.0
# UNLAWFUL USE OF HISTORIC VEHICLE                            482.0
# DRIVING WITHOUT LIGHTED HEAD LAMPS WHILE OPERAT...          387.0
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF ...          383.0
# PARTICIPATING IN SPEED CONTEST                              259.0
# FAILURE TO DISPLAY DECAL AS REQUIRED BY MVA ON ...          231.0
# DRIVING OR TAMPERING WITH VEHICLE WITHOUT OWNER...          201.0
# EXCEEDING ALLOWABLE WEIGHT                                  180.0
# FAILURE OF DRIVER INVOLVED IN ACCIDENT TO RENDE...          151.0
# ABANDONING VEHICLE ON PUBLIC PROPERTY                       114.0
# DRIFTING                                                     30.0
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO             NaN

# %%
#Creating of dataframes for each graph we will make in order to show gender comparissons of violations descriptions 
#Create dataframe to use for graph to compare men vs women comitting violation description of using
#mobile while while driving
mobile_phone_analysis = Description_Analysis_by_gender_df.loc["DRIVER USING MOBILE PHONE WHILE OPERATING VEHICLE", :]

#Create a dataframe of the top 10 most comitted violation based on the Men most comitted violations
#in order to do a gender analysis 
gender_violation_analysis_top10 = Description_Analysis_top10.iloc[0:10, 0:2]

#Create 6 different dataframes to use for graphs to compare men vs women comitting
#each different violation description
gender_violation_analysis_g1 = Description_Analysis_by_gender_df.iloc[0:10, 0:2]

gender_violation_analysis_g2 = Description_Analysis_by_gender_df.iloc[10:20, 0:2]

gender_violation_analysis_g3 = Description_Analysis_by_gender_df.iloc[20:30, 0:2]

gender_violation_analysis_g4 = Description_Analysis_by_gender_df.iloc[30:40, 0:2]

gender_violation_analysis_g5 = Description_Analysis_by_gender_df.iloc[40:50, 0:2]

gender_violation_analysis_g6 = Description_Analysis_by_gender_df.iloc[50:57, 0:2]

# %%
#Plot Data for analysis of using mobile phone while driving male vs female

#Assign variable for number of groups
n_groups = 1

#Assign 2 vairables for Y axis values
y_value_male = mobile_phone_analysis["Male description counts"].tolist()
y_value_female = mobile_phone_analysis["Female description counts"].tolist()


#Set sub plots
fig, ax = plt.subplots()

#Set index variable
index = np.arange(n_groups)

#Set bar width 
bar_width = 0.4

#create 2 different bar plots 
fig.set_size_inches(5,6)
rects1 = plt.bar(index, y_value_male, bar_width,
                 alpha= 1,
                 color= 'lightblue',
                 edgecolor='black',
                 label='Male')

rects2 = plt.bar(index + bar_width, y_value_female, bar_width,
                 alpha= .7,
                 color='pink',
                 edgecolor='black',
                 hatch = '///',
                 label='Female')

#Create Labels, Ledgend, and grid attributes 
plt.grid(True)
plt.xlabel('Gender', fontsize = 14)
plt.ylabel('Number of Violations', fontsize = 14)
plt.title('Gender Comparisson of\nUsing Mobile Phone\nWhile Operating Vehicle', fontweight="bold", fontsize = 18)
plt.xticks(index + bar_width / 2, ['Using Mobile Phone While\nOperating Vehicle'], fontsize = 12)
plt.yticks(fontsize = 12)
plt.ylim(0, 40000)
# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.04, i.get_height()+5000, \
            str(round((i.get_height()), 2)), fontsize=14, color='dimgrey',
                rotation=45)
plt.legend(fontsize = 14, frameon=True)

#Show and export PNG of graph 
plt.tight_layout()
plt.savefig("MaleVsFemaleUsingMobilePhone.png", bbox_inches="tight")

plt.show()

# %%
#Plot Data for Top 10 Violation Descriptions

#Assign variable for number of groups
n_groups = 10

#Assign 2 vairables for Y axis values
y_value_male = gender_violation_analysis_top10["Male description counts"].tolist()
y_value_female = gender_violation_analysis_top10["Female description counts"].tolist()


#Set sub plots
fig, ax = plt.subplots()

#Set index variable
index = np.arange(n_groups)

#Set bar width 
bar_width = 0.4

#create 2 different bar plots 
fig.set_size_inches(20,12)
rects1 = plt.bar(index, y_value_male, bar_width,
                 alpha= 1,
                 color= 'lightblue',
                 edgecolor='black',
                 label='Male')

rects2 = plt.bar(index + bar_width, y_value_female, bar_width,
                 alpha= .7,
                 color='pink',
                 edgecolor='black',
                 hatch = '///',
                 label='Female')

#Create Labels, Ledgend, and grid attributes 
plt.grid(True)
plt.xlabel('Violation Description', fontweight="bold", fontsize = 16)
plt.ylabel('Number of Violations', fontweight="bold", fontsize = 16)
plt.title('Gender Comparission\nof Top 10 Traffic Violations', fontweight="bold", fontsize = 18)
plt.xticks(index, ['Driving Without Valid\nLicense or Registration', 'Failure to Obey\nTraffic Control Device', 'Exceeding Posted\nSpeed Limit', 'Driving Vehicle with\nUnathorized Equipment', 'DUI', 'Improper, Fraudulent, or\nUnathorized Use of\nVehicle Registration', 'Driver Using Mobile Phone\nWhile Operating Vehicle', 'Driving Without Lighted\nHeadlights When Required', 'Driver Or Occupant Not\nRestrained by Seatbelt', 'Reckless or\nAggressive Driving'], fontsize = 14, rotation=45)
plt.yticks(fontsize = 14)
plt.ylim(0, 275000)
# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.04, i.get_height()+16000, \
            str(round((i.get_height()), 2)), fontsize=14, color='dimgrey',
                rotation=45)
plt.legend(fontsize = 14, frameon=True)


#Show and export PNG of graph 
plt.tight_layout()
plt.savefig("GenderViolationAnalysisTop10.png", bbox_inches="tight")

plt.show()

# %%
#Plot Data for violations by gender group 1 of 6

#Assign variable for number of groups
n_groups = 10

#Assign 2 vairables for Y axis values
y_value_male = gender_violation_analysis_g1["Male description counts"].tolist()
y_value_female = gender_violation_analysis_g1["Female description counts"].tolist()


#Set sub plots
fig, ax = plt.subplots()

#Set index variable
index = np.arange(n_groups)

#Set bar width 
bar_width = 0.4

#create 2 different bar plots 
fig.set_size_inches(20,12)
rects1 = plt.bar(index, y_value_male, bar_width,
                 alpha= 1,
                 color= 'lightblue',
                 edgecolor='black',
                 label='Male')

rects2 = plt.bar(index + bar_width, y_value_female, bar_width,
                 alpha= .7,
                 color='pink',
                 edgecolor='black',
                 hatch = '///',
                 label='Female')

#Create Labels, Ledgend, and grid attributes 
plt.grid(True)
plt.xlabel('Violation Description', fontweight="bold", fontsize = 14)
plt.ylabel('Number of Violations', fontweight="bold", fontsize = 14)
plt.title('Traffic Violations\nby Gender Group 1', fontweight="bold", fontsize = 18)
plt.xticks(index, ['Abandoning Vehilce\nOn Public Property', 'Elude Police', 'Drifting', 'No Seat Belt', 'Failure to Curb', 'Failure to Signal', 'Following Vehicle\nToo Close', 'Spinning Wheels', 'Using Mobile Phone', 'Violation of\nRental Agreement'], fontsize = 12, rotation=45)
plt.yticks(fontsize = 14)
plt.ylim(0, 25000)
# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.04, i.get_height()+1200, \
            str(round((i.get_height()), 2)), fontsize=14, color='dimgrey',
                rotation=45)
plt.legend(fontsize = 14, frameon=True)


#Show and export PNG of graph 
plt.tight_layout()
plt.savefig("GenderViolationAnalysisGroup1.png", bbox_inches="tight")

plt.show()

# %%
#Plot Data for violations by gender group 2 of 6

#Assign variable for number of groups
n_groups = 10

#Assign 2 vairables for Y axis values
y_value_male = gender_violation_analysis_g2["Male description counts"].tolist()
y_value_female = gender_violation_analysis_g2["Female description counts"].tolist()


#Set sub plots
fig, ax = plt.subplots()

#Set index variable
index = np.arange(n_groups)

#Set bar width 
bar_width = 0.4

#create 2 different bar plots 
fig.set_size_inches(20,12)
rects1 = plt.bar(index, y_value_male, bar_width,
                 alpha= 1,
                 color= 'lightblue',
                 edgecolor='black',
                 label='Male')

rects2 = plt.bar(index + bar_width, y_value_female, bar_width,
                 alpha= .7,
                 color='pink',
                 edgecolor='black',
                 hatch = '///',
                 label='Female')

#Create Labels, Ledgend, and grid attributes 
plt.grid(True)
plt.xlabel('Violation Description', fontweight="bold", fontsize = 14)
plt.ylabel('Number of Violations', fontweight="bold", fontsize = 14)
plt.title('Traffic Violations\nby Gender Group 2', fontweight="bold", fontsize = 18)
plt.xticks(index, ['Driving Vehilce\nWhen Not Qualified', 'Tampering Vehicle', 'Excessive Speed', 'DUI', 'Driving Using\nHeadphones', 'Unathorized Equip.', 'No Valid Medical\nExaminers Cert.', 'Obstructed View', 'Unsafe Load', 'Driving Without Insurance'], fontsize = 12, rotation=45)
plt.yticks(fontsize = 14)
plt.ylim(0, 130000)
# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.04, i.get_height()+7500, \
            str(round((i.get_height()), 2)), fontsize=14, color='dimgrey',
                rotation=45)
plt.legend(fontsize = 14, frameon=True)

#Show and export PNG of graph 
plt.tight_layout()
plt.savefig("GenderViolationAnalysisGroup2.png", bbox_inches="tight")

plt.show()

# %%
#Plot Data for violations by gender group 3 of 6

#Assign variable for number of groups
n_groups = 10

#Assign 2 vairables for Y axis values
y_value_male = gender_violation_analysis_g3["Male description counts"].tolist()
y_value_female = gender_violation_analysis_g3["Female description counts"].tolist()


#Set sub plots
fig, ax = plt.subplots()

#Set index variable
index = np.arange(n_groups)

#Set bar width 
bar_width = 0.4

#create 2 different bar plots 
fig.set_size_inches(20,12)
rects1 = plt.bar(index, y_value_male, bar_width,
                 alpha= 1,
                 color= 'lightblue',
                 edgecolor='black',
                 label='Male')

rects2 = plt.bar(index + bar_width, y_value_female, bar_width,
                 alpha= .7,
                 color='pink',
                 edgecolor='black',
                 hatch = '///',
                 label='Female')

#Create Labels, Ledgend, and grid attributes 
plt.grid(True)
plt.xlabel('Violation Description', fontweight="bold", fontsize = 14)
plt.ylabel('Number of Violations', fontweight="bold", fontsize = 14)
plt.title('Traffic Violations\nby Gender Group 3', fontweight="bold", fontsize = 18)
plt.xticks(index, ['Driving Without\nHeadlights When Required', 'Driving Without Headlights\nWhile Using Wipers', 'No Valid License or Registration', 'Exceeding Allowable Weight', 'Exceeding Posted\nSpeed Limit', 'Failing to Display\nProper Vehicle ID', 'Failure to Offer Reasonable\nAssistance to Injured Person', 'No Address Change\nWithin 30 Days', 'Not Moving for\nEmergency Vehicle', 'Failure to Control\nSpeed to Avoid Collision'], fontsize = 12, rotation=45)
plt.yticks(fontsize = 14)
plt.ylim(0, 260000)
# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.04, i.get_height()+15000, \
            str(round((i.get_height()), 2)), fontsize=14, color='dimgrey',
                rotation=45)
plt.legend(fontsize = 14, frameon=True)

#Show and export PNG of graph 
plt.tight_layout()
plt.savefig("GenderViolationAnalysisGroup3.png", bbox_inches="tight")

plt.show()

# %%
#Plot Data for violations by gender group 4 of 6

#Assign variable for number of groups
n_groups = 10

#Assign 2 vairables for Y axis values
y_value_male = gender_violation_analysis_g4["Male description counts"].tolist()
y_value_female = gender_violation_analysis_g4["Female description counts"].tolist()


#Set sub plots
fig, ax = plt.subplots()

#Set index variable
index = np.arange(n_groups)

#Set bar width 
bar_width = 0.4

#create 2 different bar plots 
fig.set_size_inches(20,12)
rects1 = plt.bar(index, y_value_male, bar_width,
                 alpha= 1,
                 color= 'lightblue',
                 edgecolor='black',
                 label='Male')

rects2 = plt.bar(index + bar_width, y_value_female, bar_width,
                 alpha= .7,
                 color='pink',
                 edgecolor='black',
                 hatch = '///',
                 label='Female')

#Create Labels, Ledgend, and grid attributes 
plt.grid(True)
plt.xlabel('Violation Description', fontweight="bold", fontsize = 14)
plt.ylabel('Number of Violations', fontweight="bold", fontsize = 14)
plt.title('Traffic Violations\nby Gender Group 4', fontweight="bold", fontsize = 18)
plt.xticks(index, ['No Decal on\nMotor Scooter', 'Failure to Drive on\nRight Side When Required', 'Failure to Furnish Written Info\non Unattended Damaged Vehicle', 'Failure to Obey\nTraffice Control Device', 'Failure to Reduce Light\nWhen Approaching Vehicle', 'Failure to Remain\nAt Scene of Accident', 'Failure to Report Accident\nor Give False Report', 'Failure to Secure\nChild in Safety Seat', 'Failure to Yield\nRight of Way', 'Unathorized Display or\nUse of Vehicle Registration'], fontsize = 12, rotation=45)
plt.yticks(fontsize = 14)
plt.ylim(0, 200000)
# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.04, i.get_height()+15000, \
            str(round((i.get_height()), 2)), fontsize=14, color='dimgrey',
                rotation=45)
plt.legend(fontsize = 14, frameon=True)

#Show and export PNG of graph 
plt.tight_layout()
plt.savefig("GenderViolationAnalysisGroup4.png", bbox_inches="tight")

plt.show()

# %%
#Plot Data for violations by gender group 5 of 6

#Assign variable for number of groups
n_groups = 10

#Assign 2 vairables for Y axis values
y_value_male = gender_violation_analysis_g5["Male description counts"].tolist()
y_value_female = gender_violation_analysis_g5["Female description counts"].tolist()


#Set sub plots
fig, ax = plt.subplots()

#Set index variable
index = np.arange(n_groups)

#Set bar width 
bar_width = 0.4

#create 2 different bar plots 
fig.set_size_inches(20,12)
rects1 = plt.bar(index, y_value_male, bar_width,
                 alpha= 1,
                 color= 'lightblue',
                 edgecolor='black',
                 label='Male')

rects2 = plt.bar(index + bar_width, y_value_female, bar_width,
                 alpha= .7,
                 color='pink',
                 edgecolor='black',
                 hatch = '///',
                 label='Female')

#Create Labels, Ledgend, and grid attributes 
plt.grid(True)
plt.xlabel('Violation Description', fontweight="bold", fontsize = 14)
plt.ylabel('Number of Violations', fontweight="bold", fontsize = 14)
plt.title('Traffic Violations\nby Gender Group 5', fontweight="bold", fontsize = 18)
plt.xticks(index, ['Letting Unathorized\nPerson Drive Vehicle', 'Littering', 'Misc.', 'Parking in Prohibited\nLocation or Manner', 'Participating in\nSpeed Contest', 'Pedestrian Crossing Roadway\nBetween Adjacent Intersection\nWith Traffic Control Signal', 'Pedestrian Failure to\nObey Traffic Control Signal', 'Provisional Driver\nWithout Authorized Person', 'Reckless or\nAggressive Driving', 'Stopping Vehicle Improperly'], fontsize = 12, rotation=45)
plt.yticks(fontsize = 14)
plt.ylim(0, 25000)
# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.04, i.get_height()+1500, \
            str(round((i.get_height()), 2)), fontsize=14, color='dimgrey',
                rotation=45)
plt.legend(fontsize = 14, frameon=True)

#Show and export PNG of graph 
plt.tight_layout()
plt.savefig("GenderViolationAnalysisGroup5.png", bbox_inches="tight")

plt.show()

# %%
#Plot Data for violations by gender group 6 of 6

#Assign variable for number of groups
n_groups = 7

#Assign 2 vairables for Y axis values
y_value_male = gender_violation_analysis_g6["Male description counts"].tolist()
y_value_female = gender_violation_analysis_g6["Female description counts"].tolist()


#Set sub plots
fig, ax = plt.subplots()

#Set index variable
index = np.arange(n_groups)

#Set bar width 
bar_width = 0.4

#create 2 different bar plots 
fig.set_size_inches(20,6)
rects1 = plt.bar(index, y_value_male, bar_width,
                 alpha= 1,
                 color= 'lightblue',
                 edgecolor='black',
                 label='Male')

rects2 = plt.bar(index + bar_width, y_value_female, bar_width,
                 alpha= .7,
                 color='pink',
                 edgecolor='black',
                 hatch = '///',
                 label='Female')

#Create Labels, Ledgend, and grid attributes 
plt.grid(True)
plt.xlabel('Violation Description', fontweight="bold", fontsize = 14)
plt.ylabel('Number of Violations', fontweight="bold", fontsize = 14)
plt.title('Traffic Violations\nby Gender Group 6', fontweight="bold", fontsize = 18)
plt.xticks(index, ['Unlawful Use of\nHistoric Vehicle', 'Unsafe Backing of Vehicle', 'Unsafe or Improper\nLane Change', 'Unsafe or Improper Passing', 'Use of Vehicle Horn When Not\nReasonably Neccessary For Safety', 'Willfully Disobeying Lawful Order\nAnd Direction of Police Officer', 'Willfully Driving Vehicle\nat Slow Speed Impeeding Normal\nand Reasonable Traffic Movement'], fontsize = 12, rotation=45)
plt.yticks(fontsize = 14)
plt.ylim(0, 20000)
# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+.04, i.get_height()+3000, \
            str(round((i.get_height()), 2)), fontsize=14, color='dimgrey',
                rotation=45)
plt.legend(fontsize = 14, frameon=True)

#Show and export PNG of graph 
plt.tight_layout()
plt.savefig("GenderViolationAnalysisGroup6.png", bbox_inches="tight")

plt.show()
